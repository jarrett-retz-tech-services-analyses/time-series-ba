# %% [markdown]
# # Get & Clean Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import seaborn as sns
sns.set()

# %%
# Download data
data = yf.download("BA SPY", start="2020-03-31", end="2020-10-01")
stocks = data['Adj Close'][:]
stocks
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
ba = data['Adj Close'][:]
ba
# Out:
#                     BA         SPY
# Date
# 2020-03-31  149.139999  253.681808
# 2020-04-01  130.699997  242.264893
# 2020-04-02  123.269997  247.855255
# 2020-04-03  124.519997  244.272705
# 2020-04-06  148.770004  260.679565
# ...                ...         ...
# 2020-09-24  146.050003  321.075287
# 2020-09-25  156.029999  326.266083
# 2020-09-28  166.080002  331.685181
# 2020-09-29  163.600006  329.878784
# 2020-09-30  165.259995  332.379944
#
# [128 rows x 2 columns]

# %%
# Calculate data from prices
for col in ba.columns:
    # Daily Returns for each column
    ba[f'{col}_ret'] = ba[col].diff(1)

    # Starting value normalization for each col
    start_val_price = ba[col].iloc[0]
    start_val_ret = ba[f'{col}_ret'].iloc[1]
    
    ba[f'norm_{col}_price'] = ba[col].div(start_val_price).mul(100)
    ba[f'norm_{col}_ret'] = ba[f'{col}_ret'].div(start_val_ret).mul(100)
    
    # Smooth returns with 7 day rolling average for normalized daily returns
    ba[f'7d_roll_avg_norm_{col}_price'] = ba[f'norm_{col}_price'].rolling(window=7).mean()
    ba[f'7d_roll_avg_norm_{col}_ret'] = ba[f'norm_{col}_ret'].rolling(window=7).mean()

ba.head(10)
# Out:
#                     BA         SPY     BA_ret  norm_BA_price  norm_BA_ret  \
# Date
# 2020-03-31  149.139999  253.681808        NaN     100.000000          NaN
# 2020-04-01  130.699997  242.264893 -18.440002      87.635777   100.000000
# 2020-04-02  123.269997  247.855255  -7.430000      82.653880    40.292838
# 2020-04-03  124.519997  244.272705   1.250000      83.492019    -6.778741
# 2020-04-06  148.770004  260.679565  24.250008      99.751914  -131.507616
# 2020-04-07  141.580002  260.945343  -7.190002      94.930939    38.991331
# 2020-04-08  146.869995  269.704834   5.289993      98.477937   -28.687595
# 2020-04-09  151.839996  273.809021   4.970001     101.810377   -26.952281
# 2020-04-13  147.330002  271.309113  -4.509995      98.786377    24.457668
# 2020-04-14  141.000000  279.310822  -6.330002      94.542041    34.327554
#
#             7d_roll_avg_norm_BA_price  7d_roll_avg_norm_BA_ret    SPY_ret  \
# Date
# 2020-03-31                        NaN                      NaN        NaN
# 2020-04-01                        NaN                      NaN -11.416916
# 2020-04-02                        NaN                      NaN   5.590363
# 2020-04-03                        NaN                      NaN  -3.582550
# 2020-04-06                        NaN                      NaN  16.406860
# 2020-04-07                        NaN                      NaN   0.265778
# 2020-04-08                  92.420352                      NaN   8.759491
# 2020-04-09                  92.678978                -2.091723   4.104187
# 2020-04-13                  94.271921               -12.883485  -2.499908
# 2020-04-14                  95.970229               -13.735669   8.001709
#
#             norm_SPY_price  norm_SPY_ret  7d_roll_avg_norm_SPY_price  \
# Date
# 2020-03-31      100.000000           NaN                         NaN
# 2020-04-01       95.499513    100.000000                         NaN
# 2020-04-02       97.703204    -48.965610                         NaN
# 2020-04-03       96.290982     31.379315                         NaN
# 2020-04-06      102.758478   -143.706589                         NaN
# 2020-04-07      102.863246     -2.327928                         NaN
# 2020-04-08      106.316190    -76.723793                  100.204516
# 2020-04-09      107.934039    -35.948299                  101.337950
# 2020-04-13      106.948588     21.896530                  102.973532
# 2020-04-14      110.102819    -70.086432                  104.744906
#
#             7d_roll_avg_norm_SPY_ret
# Date
# 2020-03-31                       NaN
# 2020-04-01                       NaN
# 2020-04-02                       NaN
# 2020-04-03                       NaN
# 2020-04-06                       NaN
# 2020-04-07                       NaN
# 2020-04-08                       NaN
# 2020-04-09                -25.184701
# 2020-04-13                -36.342339
# 2020-04-14                -39.359599

# %%
# Load COVID Data
covid_data = pd.read_csv('./all-states-history.csv', parse_dates=True, index_col=0)
covid_data
# Out:
#            state dataQualityGrade   death  deathConfirmed  deathIncrease  \
# date
# 2020-10-02    WY                B    53.0             NaN              0
# 2020-10-02    NE                A   493.0             NaN             15
# 2020-10-02    ND                B   191.0           188.0              0
# 2020-10-02    NC               A+  3608.0          3579.0             29
# 2020-10-02    MT                C   186.0             NaN              5
# ...          ...              ...     ...             ...            ...
# 2020-01-24    WA              NaN     NaN             NaN              0
# 2020-01-23    WA              NaN     NaN             NaN              0
# 2020-01-23    MA              NaN     NaN             NaN              0
# 2020-01-22    WA              NaN     NaN             NaN              0
# 2020-01-22    MA              NaN     NaN             NaN              0
#
#             deathProbable  hospitalized  hospitalizedCumulative  \
# date
# 2020-10-02            NaN         280.0                   280.0
# 2020-10-02            NaN        2356.0                  2356.0
# 2020-10-02            3.0         902.0                   902.0
# 2020-10-02           29.0           NaN                     NaN
# 2020-10-02            NaN         729.0                   729.0
# ...                   ...           ...                     ...
# 2020-01-24            NaN           NaN                     NaN
# 2020-01-23            NaN           NaN                     NaN
# 2020-01-23            NaN           NaN                     NaN
# 2020-01-22            NaN           NaN                     NaN
# 2020-01-22            NaN           NaN                     NaN
#
#             hospitalizedCurrently  hospitalizedIncrease  ...  \
# date                                                     ...
# 2020-10-02                   32.0                     6  ...
# 2020-10-02                  227.0                     7  ...
# 2020-10-02                  111.0                    18  ...
# 2020-10-02                  921.0                     0  ...
# 2020-10-02                  177.0                     2  ...
# ...                           ...                   ...  ...
# 2020-01-24                    NaN                     0  ...
# 2020-01-23                    NaN                     0  ...
# 2020-01-23                    NaN                     0  ...
# 2020-01-22                    NaN                     0  ...
# 2020-01-22                    NaN                     0  ...
#
#             totalTestResults  totalTestResultsIncrease  totalTestsAntibody  \
# date
# 2020-10-02          103278.0                      1983                 NaN
# 2020-10-02          464264.0                      4722                 NaN
# 2020-10-02          626450.0                      7119              9731.0
# 2020-10-02         3099704.0                     36043                 NaN
# 2020-10-02          353362.0                      4653                 NaN
# ...                      ...                       ...                 ...
# 2020-01-24               0.0                         0                 NaN
# 2020-01-23               0.0                         0                 NaN
# 2020-01-23               2.0                         1                 NaN
# 2020-01-22               0.0                         0                 NaN
# 2020-01-22               1.0                         0                 NaN
#
#             totalTestsAntigen  totalTestsPeopleAntibody  \
# date
# 2020-10-02                NaN                       NaN
# 2020-10-02                NaN                       NaN
# 2020-10-02                NaN                       NaN
# 2020-10-02             3063.0                       NaN
# 2020-10-02                NaN                       NaN
# ...                       ...                       ...
# 2020-01-24                NaN                       NaN
# 2020-01-23                NaN                       NaN
# 2020-01-23                NaN                       NaN
# 2020-01-22                NaN                       NaN
# 2020-01-22                NaN                       NaN
#
#             totalTestsPeopleAntigen  totalTestsPeopleViral  \
# date
# 2020-10-02                      NaN               102353.0
# 2020-10-02                      NaN               464576.0
# 2020-10-02                      NaN               244312.0
# 2020-10-02                      NaN                    NaN
# 2020-10-02                      NaN                    NaN
# ...                             ...                    ...
# 2020-01-24                      NaN                    NaN
# 2020-01-23                      NaN                    NaN
# 2020-01-23                      NaN                    NaN
# 2020-01-22                      NaN                    NaN
# 2020-01-22                      NaN                    NaN
#
#             totalTestsPeopleViralIncrease  totalTestsViral  \
# date
# 2020-10-02                           2095         165242.0
# 2020-10-02                           4731         634687.0
# 2020-10-02                           1412         649885.0
# 2020-10-02                              0        3094417.0
# 2020-10-02                              0         353362.0
# ...                                   ...              ...
# 2020-01-24                              0              NaN
# 2020-01-23                              0              NaN
# 2020-01-23                              0              2.0
# 2020-01-22                              0              NaN
# 2020-01-22                              0              1.0
#
#             totalTestsViralIncrease
# date
# 2020-10-02                     1454
# 2020-10-02                     9733
# 2020-10-02                     7432
# 2020-10-02                    35876
# 2020-10-02                     4653
# ...                             ...
# 2020-01-24                        0
# 2020-01-23                        0
# 2020-01-23                        1
# 2020-01-22                        0
# 2020-01-22                        1
#
# [11914 rows x 42 columns]

# %%
covid = covid_data.groupby('date').sum()[['deathIncrease']]

start_date = '2020-03-31'
end_date = '2020-10-01'

covid = covid.loc[start_date:end_date]
covid
# Out:
#             deathIncrease
# date
# 2020-03-31            890
# 2020-04-01           1011
# 2020-04-02           1172
# 2020-04-03           1286
# 2020-04-04           1482
# ...                   ...
# 2020-09-27            307
# 2020-09-28            257
# 2020-09-29            739
# 2020-09-30           1061
# 2020-10-01            851
#
# [185 rows x 1 columns]

# %%
# Create more data columns
for col in covid.columns:
    # Daily differences
    covid[f'{col}_diff'] = covid[col].diff(1)
    
    # Normalized
    first_non_null_val = covid[f'{col}_diff'].iloc[1]
    
    covid[f'norm_{col}_diff'] = covid[f'{col}_diff'].div(first_non_null_val).mul(100)
    
    # Norm Rolling
    covid[f'7d_roll_avg_norm_{col}'] = covid[f'norm_{col}_diff'].rolling(window=7).mean()
    
covid.head()
# Out:
#              death  positive  death_diff  norm_death_diff  \
# date
# 2020-03-31  4313.0  198295.0         NaN              NaN
# 2020-04-01  5324.0  224086.0      1011.0       100.000000
# 2020-04-02  6496.0  252146.0      1172.0       115.924827
# 2020-04-03  7782.0  284222.0      1286.0       127.200791
# 2020-04-04  9264.0  317434.0      1482.0       146.587537
#
#             7d_roll_avg_norm_death  positive_diff  norm_positive_diff  \
# date
# 2020-03-31                     NaN            NaN                 NaN
# 2020-04-01                     NaN        25791.0          100.000000
# 2020-04-02                     NaN        28060.0          108.797643
# 2020-04-03                     NaN        32076.0          124.368966
# 2020-04-04                     NaN        33212.0          128.773603
#
#             7d_roll_avg_norm_positive
# date
# 2020-03-31                        NaN
# 2020-04-01                        NaN
# 2020-04-02                        NaN
# 2020-04-03                        NaN
# 2020-04-04                        NaN

# %%
df_comb = ba.join(covid)
df_comb
# Out:
#                     BA         SPY     BA_ret  norm_BA_price  norm_BA_ret  \
# Date
# 2020-03-31  149.139999  253.681808        NaN     100.000000          NaN
# 2020-04-01  130.699997  242.264893 -18.440002      87.635777   100.000000
# 2020-04-02  123.269997  247.855255  -7.430000      82.653880    40.292838
# 2020-04-03  124.519997  244.272705   1.250000      83.492019    -6.778741
# 2020-04-06  148.770004  260.679565  24.250008      99.751914  -131.507616
# ...                ...         ...        ...            ...          ...
# 2020-09-24  146.050003  321.075287  -5.129990      97.928124    27.819897
# 2020-09-25  156.029999  326.266083   9.979996     104.619820   -54.121445
# 2020-09-28  166.080002  331.685181  10.050003     111.358457   -54.501094
# 2020-09-29  163.600006  329.878784  -2.479996     109.695593    13.448999
# 2020-09-30  165.259995  332.379944   1.659988     110.808633    -9.002105
#
#             7d_roll_avg_norm_BA_price  7d_roll_avg_norm_BA_ret    SPY_ret  \
# Date
# 2020-03-31                        NaN                      NaN        NaN
# 2020-04-01                        NaN                      NaN -11.416916
# 2020-04-02                        NaN                      NaN   5.590363
# 2020-04-03                        NaN                      NaN  -3.582550
# 2020-04-06                        NaN                      NaN  16.406860
# ...                               ...                      ...        ...
# 2020-09-24                 105.989580                13.511001   0.853546
# 2020-09-25                 104.894730                 8.854979   5.190796
# 2020-09-28                 104.755839                 1.123332   5.419098
# 2020-09-29                 104.991476                -1.905800  -1.806396
# 2020-09-30                 105.844940                -6.902686   2.501160
#
#             norm_SPY_price  norm_SPY_ret  7d_roll_avg_norm_SPY_price  \
# Date
# 2020-03-31      100.000000           NaN                         NaN
# 2020-04-01       95.499513    100.000000                         NaN
# 2020-04-02       97.703204    -48.965610                         NaN
# 2020-04-03       96.290982     31.379315                         NaN
# 2020-04-06      102.758478   -143.706589                         NaN
# ...                    ...           ...                         ...
# 2020-09-24      126.566146     -7.476153                  128.887323
# 2020-09-25      128.612329    -45.465833                  128.398882
# 2020-09-28      130.748508    -47.465515                  128.381500
# 2020-09-29      130.036437     15.822106                  128.477633
# 2020-09-30      131.022380    -21.907490                  128.920294
#
#             7d_roll_avg_norm_SPY_ret     death   positive  death_diff  \
# Date
# 2020-03-31                       NaN    4313.0   198295.0         NaN
# 2020-04-01                       NaN    5324.0   224086.0      1011.0
# 2020-04-02                       NaN    6496.0   252146.0      1172.0
# 2020-04-03                       NaN    7782.0   284222.0      1286.0
# 2020-04-06                       NaN   11922.0   371936.0      1318.0
# ...                              ...       ...        ...         ...
# 2020-09-24                 19.018114  194848.0  6942070.0       921.0
# 2020-09-25                 10.853087  195692.0  6997596.0       844.0
# 2020-09-28                  0.386212  197125.0  7117430.0       257.0
# 2020-09-29                 -2.136044  197864.0  7154377.0       739.0
# 2020-09-30                 -9.835852  198925.0  7198801.0      1061.0
#
#             norm_death_diff  7d_roll_avg_norm_death  positive_diff  \
# Date
# 2020-03-31              NaN                     NaN            NaN
# 2020-04-01       100.000000                     NaN        25791.0
# 2020-04-02       115.924827                     NaN        28060.0
# 2020-04-03       127.200791                     NaN        32076.0
# 2020-04-06       130.365974                     NaN        29002.0
# ...                     ...                     ...            ...
# 2020-09-24        91.097923               73.322029        43772.0
# 2020-09-25        83.481701               72.516603        55526.0
# 2020-09-28        25.420376               73.632895        36524.0
# 2020-09-29        73.095945               72.007913        36947.0
# 2020-09-30       104.945598               70.623145        44424.0
#
#             norm_positive_diff  7d_roll_avg_norm_positive
# Date
# 2020-03-31                 NaN                        NaN
# 2020-04-01          100.000000                        NaN
# 2020-04-02          108.797643                        NaN
# 2020-04-03          124.368966                        NaN
# 2020-04-06          112.450079                        NaN
# ...                        ...                        ...
# 2020-09-24          169.718119                 166.500496
# 2020-09-25          215.292156                 170.953876
# 2020-09-28          141.615292                 170.124684
# 2020-09-29          143.255399                 163.205326
# 2020-09-30          172.246132                 166.449537
#
# [128 rows x 20 columns]

# %%
import plotly.express as px

# %%
fig = px.line(df_comb)

fig.update_layout(dict(
    title="Prices, Avgs, Returns, Deaths, Positives"
))
fig.show()
# Out:
# <div>                            <div id="9ad52877-447d-4359-9dea-00bf095476f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ad52877-447d-4359-9dea-00bf095476f1")) {                    Plotly.newPlot(                        "9ad52877-447d-4359-9dea-00bf095476f1",                        [{"hovertemplate": "variable=BA<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "BA", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "BA", "showlegend": true, "type": "scattergl", "x": ["2020-03-31T00:00:00", "2020-04-01T00:00:00", "2020-04-02T00:00:00", "2020-04-03T00:00:00", "2020-04-06T00:00:00", "2020-04-07T00:00:00", "2020-04-08T00:00:00", "2020-04-09T00:00:00", "2020-04-13T00:00:00", "2020-04-14T00:00:00", "2020-04-15T00:00:00", "2020-04-16T00:00:00", "2020-04-17T00:00:00", "2020-04-20T00:00:00", "2020-04-21T00:00:00", "2020-04-22T00:00:00", "2020-04-23T00:00:00", "2020-04-24T00:00:00", "2020-04-27T00:00:00", "2020-04-28T00:00:00", "2020-04-29T00:00:00", "2020-04-30T00:00:00", "2020-05-01T00:00:00", "2020-05-04T00:00:00", "2020-05-05T00:00:00", "2020-05-06T00:00:00", "2020-05-07T00:00:00", "2020-05-08T00:00:00", "2020-05-11T00:00:00", "2020-05-12T00:00:00", "2020-05-13T00:00:00", "2020-05-14T00:00:00", "2020-05-15T00:00:00", "2020-05-18T00:00:00", "2020-05-19T00:00:00", "2020-05-20T00:00:00", "2020-05-21T00:00:00", "2020-05-22T00:00:00", "2020-05-26T00:00:00", "2020-05-27T00:00:00", "2020-05-28T00:00:00", "2020-05-29T00:00:00", "2020-06-01T00:00:00", "2020-06-02T00:00:00", "2020-06-03T00:00:00", "2020-06-04T00:00:00", "2020-06-05T00:00:00", "2020-06-08T00:00:00", "2020-06-09T00:00:00", "2020-06-10T00:00:00", "2020-06-11T00:00:00", "2020-06-12T00:00:00", "2020-06-15T00:00:00", "2020-06-16T00:00:00", "2020-06-17T00:00:00", "2020-06-18T00:00:00", "2020-06-19T00:00:00", "2020-06-22T00:00:00", "2020-06-23T00:00:00", "2020-06-24T00:00:00", "2020-06-25T00:00:00", "2020-06-26T00:00:00", "2020-06-29T00:00:00", "2020-06-30T00:00:00", "2020-07-01T00:00:00", "2020-07-02T00:00:00", "2020-07-06T00:00:00", "2020-07-07T00:00:00", "2020-07-08T00:00:00", "2020-07-09T00:00:00", "2020-07-10T00:00:00", "2020-07-13T00:00:00", "2020-07-14T00:00:00", "2020-07-15T00:00:00", "2020-07-16T00:00:00", "2020-07-17T00:00:00", "2020-07-20T00:00:00", "2020-07-21T00:00:00", "2020-07-22T00:00:00", "2020-07-23T00:00:00", "2020-07-24T00:00:00", "2020-07-27T00:00:00", "2020-07-28T00:00:00", "2020-07-29T00:00:00", "2020-07-30T00:00:00", "2020-07-31T00:00:00", "2020-08-03T00:00:00", "2020-08-04T00:00:00", "2020-08-05T00:00:00", "2020-08-06T00:00:00", "2020-08-07T00:00:00", "2020-08-10T00:00:00", "2020-08-11T00:00:00", "2020-08-12T00:00:00", "2020-08-13T00:00:00", "2020-08-14T00:00:00", "2020-08-17T00:00:00", "2020-08-18T00:00:00", "2020-08-19T00:00:00", "2020-08-20T00:00:00", "2020-08-21T00:00:00", "2020-08-24T00:00:00", "2020-08-25T00:00:00", "2020-08-26T00:00:00", "2020-08-27T00:00:00", "2020-08-28T00:00:00", "2020-08-31T00:00:00", "2020-09-01T00:00:00", "2020-09-02T00:00:00", "2020-09-03T00:00:00", "2020-09-04T00:00:00", "2020-09-08T00:00:00", "2020-09-09T00:00:00", "2020-09-10T00:00:00", "2020-09-11T00:00:00", "2020-09-14T00:00:00", "2020-09-15T00:00:00", "2020-09-16T00:00:00", "2020-09-17T00:00:00", "2020-09-18T00:00:00", "2020-09-21T00:00:00", "2020-09-22T00:00:00", "2020-09-23T00:00:00", "2020-09-24T00:00:00", "2020-09-25T00:00:00", "2020-09-28T00:00:00", "2020-09-29T00:00:00", "2020-09-30T00:00:00"], "xaxis": "x", "y": [149.13999938964844, 130.6999969482422, 123.2699966430664, 124.5199966430664, 148.77000427246094, 141.5800018310547, 146.8699951171875, 151.83999633789062, 147.3300018310547, 141.0, 145.97999572753906, 134.24000549316406, 154.0, 143.61000061035156, 136.3300018310547, 134.970001220703 ...

# %%
cols = [
    '7d_roll_avg_norm_death',
    '7d_roll_avg_norm_positive',
    '7d_roll_avg_norm_BA_ret',
    '7d_roll_avg_norm_SPY_ret'
]

fig = px.line(df_comb[cols])

fig.update_layout(dict(
    title="Seven Day Rolling Avgs for Returns, Positives, and Deaths"
))
fig.show()
# Out:
# <div>                            <div id="0926baa3-c839-4c01-85a9-43c04fdfb663" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0926baa3-c839-4c01-85a9-43c04fdfb663")) {                    Plotly.newPlot(                        "0926baa3-c839-4c01-85a9-43c04fdfb663",                        [{"hovertemplate": "variable=7d_roll_avg_norm_death<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "7d_roll_avg_norm_death", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "7d_roll_avg_norm_death", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-03-31T00:00:00", "2020-04-01T00:00:00", "2020-04-02T00:00:00", "2020-04-03T00:00:00", "2020-04-06T00:00:00", "2020-04-07T00:00:00", "2020-04-08T00:00:00", "2020-04-09T00:00:00", "2020-04-13T00:00:00", "2020-04-14T00:00:00", "2020-04-15T00:00:00", "2020-04-16T00:00:00", "2020-04-17T00:00:00", "2020-04-20T00:00:00", "2020-04-21T00:00:00", "2020-04-22T00:00:00", "2020-04-23T00:00:00", "2020-04-24T00:00:00", "2020-04-27T00:00:00", "2020-04-28T00:00:00", "2020-04-29T00:00:00", "2020-04-30T00:00:00", "2020-05-01T00:00:00", "2020-05-04T00:00:00", "2020-05-05T00:00:00", "2020-05-06T00:00:00", "2020-05-07T00:00:00", "2020-05-08T00:00:00", "2020-05-11T00:00:00", "2020-05-12T00:00:00", "2020-05-13T00:00:00", "2020-05-14T00:00:00", "2020-05-15T00:00:00", "2020-05-18T00:00:00", "2020-05-19T00:00:00", "2020-05-20T00:00:00", "2020-05-21T00:00:00", "2020-05-22T00:00:00", "2020-05-26T00:00:00", "2020-05-27T00:00:00", "2020-05-28T00:00:00", "2020-05-29T00:00:00", "2020-06-01T00:00:00", "2020-06-02T00:00:00", "2020-06-03T00:00:00", "2020-06-04T00:00:00", "2020-06-05T00:00:00", "2020-06-08T00:00:00", "2020-06-09T00:00:00", "2020-06-10T00:00:00", "2020-06-11T00:00:00", "2020-06-12T00:00:00", "2020-06-15T00:00:00", "2020-06-16T00:00:00", "2020-06-17T00:00:00", "2020-06-18T00:00:00", "2020-06-19T00:00:00", "2020-06-22T00:00:00", "2020-06-23T00:00:00", "2020-06-24T00:00:00", "2020-06-25T00:00:00", "2020-06-26T00:00:00", "2020-06-29T00:00:00", "2020-06-30T00:00:00", "2020-07-01T00:00:00", "2020-07-02T00:00:00", "2020-07-06T00:00:00", "2020-07-07T00:00:00", "2020-07-08T00:00:00", "2020-07-09T00:00:00", "2020-07-10T00:00:00", "2020-07-13T00:00:00", "2020-07-14T00:00:00", "2020-07-15T00:00:00", "2020-07-16T00:00:00", "2020-07-17T00:00:00", "2020-07-20T00:00:00", "2020-07-21T00:00:00", "2020-07-22T00:00:00", "2020-07-23T00:00:00", "2020-07-24T00:00:00", "2020-07-27T00:00:00", "2020-07-28T00:00:00", "2020-07-29T00:00:00", "2020-07-30T00:00:00", "2020-07-31T00:00:00", "2020-08-03T00:00:00", "2020-08-04T00:00:00", "2020-08-05T00:00:00", "2020-08-06T00:00:00", "2020-08-07T00:00:00", "2020-08-10T00:00:00", "2020-08-11T00:00:00", "2020-08-12T00:00:00", "2020-08-13T00:00:00", "2020-08-14T00:00:00", "2020-08-17T00:00:00", "2020-08-18T00:00:00", "2020-08-19T00:00:00", "2020-08-20T00:00:00", "2020-08-21T00:00:00", "2020-08-24T00:00:00", "2020-08-25T00:00:00", "2020-08-26T00:00:00", "2020-08-27T00:00:00", "2020-08-28T00:00:00", "2020-08-31T00:00:00", "2020-09-01T00:00:00", "2020-09-02T00:00:00", "2020-09-03T00:00:00", "2020-09-04T00:00:00", "2020-09-08T00:00:00", "2020-09-09T00:00:00", "2020-09-10T00:00:00", "2020-09-11T00:00:00", "2020-09-14T00:00:00", "2020-09-15T00:00:00", "2020-09-16T00:00:00", "2020-09-17T00:00:00", "2020-09-18T00:00:00", "2020-09-21T00:00:00", "2020-09-22T00:00:00", "2020-09-23T00:00:00", "2020-09-24T00:00:00", "2020-09-25T00:00:00", "2020-09-28T00:00:00", "2020-09-29T00:00:00", "2020-09-30T00:00:00"], "xaxis": "x", "y": [null, null, null, null, null, 136.1169987282747, 150.23314963967783, 162.54062455842873, 191.95987000141304, 196.3685177335029, 203.914087890349, 206.13254203758655, 206.2879751307051, 207.17818284583862,  ...

# %%
df_comb[cols].corr()
# Out:
#                            7d_roll_avg_norm_death  7d_roll_avg_norm_positive  \
# 7d_roll_avg_norm_death                   1.000000                  -0.343445
# 7d_roll_avg_norm_positive               -0.343445                   1.000000
# 7d_roll_avg_norm_BA_ret                  0.052743                   0.283568
# 7d_roll_avg_norm_SPY_ret                -0.305913                   0.024351
#
#                            7d_roll_avg_norm_BA_ret  7d_roll_avg_norm_SPY_ret
# 7d_roll_avg_norm_death                    0.052743                 -0.305913
# 7d_roll_avg_norm_positive                 0.283568                  0.024351
# 7d_roll_avg_norm_BA_ret                   1.000000                  0.592298
# 7d_roll_avg_norm_SPY_ret                  0.592298                  1.000000

# %%
## Testing for stationarity with DF test
import statsmodels.tsa.stattools as sts

# %%
for col in cols:
    test_stat, p_value, lags, obs, crit_vals, ic = sts.adfuller(df_comb[col].dropna())
    print(str(col))
    print('Test statistic:\t\t' + str(test_stat))
    print('Critical values:\t' + str(crit_vals))
    print('P-value:\t\t' + str(p_value))
    print('\n\n')
# Out:
# 7d_roll_avg_norm_death
# Test statistic:		-3.011001369305491
# Critical values:	{'1%': -3.49181775886872, '5%': -2.8884437992971588, '10%': -2.5811201893779985}
# P-value:		0.03387970538879231
#
#
#
# 7d_roll_avg_norm_positive
# Test statistic:		-1.8079723198152358
# Critical values:	{'1%': -3.4865346059036564, '5%': -2.8861509858476264, '10%': -2.579896092790057}
# P-value:		0.3765109032255625
#
#
#
# 7d_roll_avg_norm_BA_ret
# Test statistic:		-3.198247732167936
# Critical values:	{'1%': -3.49181775886872, '5%': -2.8884437992971588, '10%': -2.5811201893779985}
# P-value:		0.020086331671170687
#
#
#
# 7d_roll_avg_norm_SPY_ret
# Test statistic:		-3.305162758716354
# Critical values:	{'1%': -3.49181775886872, '5%': -2.8884437992971588, '10%': -2.5811201893779985}
# P-value:		0.014649270391207737

# %% [markdown]
# With a 5% level of significance, we observe that three columns in the selected columns are from a stationary series of data.
#
# - 7d_roll_avg_norm_death
# - 7d_roll_avg_norm_BA_ret
# - 7d_roll_avg_norm_SPY_ret

# %%
df_sel = df_comb.copy()[[
    '7d_roll_avg_norm_death',
    '7d_roll_avg_norm_BA_ret',
    '7d_roll_avg_norm_SPY_ret',
    'BA',
    'SPY'
]]

df_sel.dropna().head()
# Out:
#             7d_roll_avg_norm_death  7d_roll_avg_norm_BA_ret  \
# Date
# 2020-04-09              162.540625                -2.091723
# 2020-04-13              191.959870               -12.883485
# 2020-04-14              196.368518               -13.735669
# 2020-04-15              203.914088               -16.625346
# 2020-04-16              206.132542                11.256583
#
#             7d_roll_avg_norm_SPY_ret          BA         SPY
# Date
# 2020-04-09                -25.184701  151.839996  273.809021
# 2020-04-13                -36.342339  147.330002  271.309113
# 2020-04-14                -39.359599  141.000000  279.310822
# 2020-04-15                -36.416229  145.979996  273.375977
# 2020-04-16                -17.536959  134.240005  274.694824

# %%
df_sel.corr()
# Out:
#                           7d_roll_avg_norm_death  7d_roll_avg_norm_BA_ret  \
# 7d_roll_avg_norm_death                  1.000000                 0.052743
# 7d_roll_avg_norm_BA_ret                 0.052743                 1.000000
# 7d_roll_avg_norm_SPY_ret               -0.305913                 0.592298
# BA                                     -0.748761                -0.348309
# SPY                                    -0.669721                -0.003910
#
#                           7d_roll_avg_norm_SPY_ret        BA       SPY
# 7d_roll_avg_norm_death                   -0.305913 -0.748761 -0.669721
# 7d_roll_avg_norm_BA_ret                   0.592298 -0.348309 -0.003910
# 7d_roll_avg_norm_SPY_ret                  1.000000 -0.039820  0.166964
# BA                                       -0.039820  1.000000  0.623246
# SPY                                       0.166964  0.623246  1.000000

# %%
ba_only = ba[['BA']]
ba_only
# Out:
#                     BA
# Date
# 2020-03-31  149.139999
# 2020-04-01  130.699997
# 2020-04-02  123.269997
# 2020-04-03  124.519997
# 2020-04-06  148.770004
# ...                ...
# 2020-09-24  146.050003
# 2020-09-25  156.029999
# 2020-09-28  166.080002
# 2020-09-29  163.600006
# 2020-09-30  165.259995
#
# [128 rows x 1 columns]

# %%
from pmdarima.arima import auto_arima

# %%
model_auto = auto_arima(ba_only.BA)

# %%
model_auto.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  128
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                -448.054
# Date:                Tue, 13 Apr 2021   AIC                            898.108
# Time:                        11:26:13   BIC                            900.952
# Sample:                             0   HQIC                           899.264
#                                 - 128
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        67.9039      5.449     12.461      0.000      57.224      78.584
# ===================================================================================
# Ljung-Box (Q):                       48.89   Jarque-Bera (JB):                46.28
# Prob(Q):                              0.16   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.37   Skew:                             0.36
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.87
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
size = int(len(ba_only)*0.8)
df_train = ba_only.iloc[:size]
df_test = ba_only.iloc[size:]

# %%
model_auto = auto_arima(df.BA)

# %%
df_comb = ba.join(covid)
df_comb
# Out:
#                     BA         SPY  deathIncrease
# Date
# 2020-03-31  149.139999  253.681808            890
# 2020-04-01  130.699997  242.264893           1011
# 2020-04-02  123.269997  247.855255           1172
# 2020-04-03  124.519997  244.272705           1286
# 2020-04-06  148.770004  260.679565           1318
# ...                ...         ...            ...
# 2020-09-24  146.050003  321.075287            921
# 2020-09-25  156.029999  326.266083            844
# 2020-09-28  166.080002  331.685181            257
# 2020-09-29  163.600006  329.878784            739
# 2020-09-30  165.259995  332.379944           1061
#
# [128 rows x 3 columns]

# %%
df_comb['rolling_7dd'] = df_comb.deathIncrease.rolling(window=7).mean()
df_comb
# Out:
#                     BA         SPY  deathIncrease  rolling_7dd
# Date
# 2020-03-31  149.139999  253.681808            890          NaN
# 2020-04-01  130.699997  242.264893           1011          NaN
# 2020-04-02  123.269997  247.855255           1172          NaN
# 2020-04-03  124.519997  244.272705           1286          NaN
# 2020-04-06  148.770004  260.679565           1318          NaN
# ...                ...         ...            ...          ...
# 2020-09-24  146.050003  321.075287            921   883.571429
# 2020-09-25  156.029999  326.266083            844   832.714286
# 2020-09-28  166.080002  331.685181            257   746.142857
# 2020-09-29  163.600006  329.878784            739   723.000000
# 2020-09-30  165.259995  332.379944           1061   833.571429
#
# [128 rows x 4 columns]

# %%
df_comb = df_comb.pct_change(1)
df_comb
# Out:
#                   BA       SPY  deathIncrease
# Date
# 2020-03-31       NaN       NaN            NaN
# 2020-04-01 -0.123642 -0.045005       0.135955
# 2020-04-02 -0.056848  0.023075       0.159248
# 2020-04-03  0.010140 -0.014454       0.097270
# 2020-04-06  0.194748  0.067166       0.024883
# ...              ...       ...            ...
# 2020-09-24 -0.033933  0.002665      -0.205349
# 2020-09-25  0.068333  0.016167      -0.083605
# 2020-09-28  0.064411  0.016609      -0.695498
# 2020-09-29 -0.014933 -0.005446       1.875486
# 2020-09-30  0.010147  0.007582       0.435724
#
# [128 rows x 3 columns]

# %%
size = int(len(df_comb)*0.8)
df_train = df_comb.iloc[:size]
df_test = df_comb.iloc[size:]
df_train
# Out:
#                     BA         SPY  deathIncrease  rolling_7dd
# Date
# 2020-03-31  149.139999  253.681808            890          NaN
# 2020-04-01  130.699997  242.264893           1011          NaN
# 2020-04-02  123.269997  247.855255           1172          NaN
# 2020-04-03  124.519997  244.272705           1286          NaN
# 2020-04-06  148.770004  260.679565           1318          NaN
# ...                ...         ...            ...          ...
# 2020-08-18  170.229996  334.761780           1196  1036.142857
# 2020-08-19  169.270004  333.367920           1420  1178.142857
# 2020-08-20  169.580002  334.405914           1134  1150.714286
# 2020-08-21  167.500000  335.592133           1123  1094.142857
# 2020-08-24  178.270004  338.992767            343   977.000000
#
# [102 rows x 4 columns]

# %%
model_auto = auto_arima(df_train.BA.dropna())
model_auto.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  102
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                -364.346
# Date:                Tue, 13 Apr 2021   AIC                            730.692
# Time:                        11:48:09   BIC                            733.307
# Sample:                             0   HQIC                           731.751
#                                 - 102
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        79.5909      7.608     10.461      0.000      64.679      94.503
# ===================================================================================
# Ljung-Box (Q):                       46.50   Jarque-Bera (JB):                23.77
# Prob(Q):                              0.22   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.31   Skew:                             0.30
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model_auto_ex = auto_arima(
    df_train.dropna().BA.pct_change(1)[1:],
    exogenous= df_train.dropna()[['SPY', 'rolling_7dd']][1:]
)

# %%
model_auto_ex.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   95
# Model:                        SARIMAX   Log Likelihood                 148.303
# Date:                Tue, 13 Apr 2021   AIC                           -288.606
# Time:                        11:53:27   BIC                           -278.390
# Sample:                             0   HQIC                          -284.478
#                                  - 95
# Covariance Type:                  opg
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# intercept      -0.0001      0.159     -0.001      0.999      -0.312       0.312
# SPY          3.088e-05      0.000      0.063      0.950      -0.001       0.001
# rolling_7dd -4.869e-06   1.41e-05     -0.346      0.729   -3.24e-05    2.27e-05
# sigma2          0.0026      0.000      8.552      0.000       0.002       0.003
# ===================================================================================
# Ljung-Box (Q):                       64.37   Jarque-Bera (JB):                16.31
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.29   Skew:                             0.60
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.64
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import seaborn as sns
sns.set()

# %%
# Download data
data = yf.download("BA SPY", start="2020-03-31", end="2020-10-01")
stocks = data['Adj Close'][:]
stocks
# Out:
# [*********************100%***********************]  2 of 2 completed
#                     BA         SPY
# Date
# 2020-03-31  149.139999  253.681808
# 2020-04-01  130.699997  242.264893
# 2020-04-02  123.269997  247.855255
# 2020-04-03  124.519997  244.272705
# 2020-04-06  148.770004  260.679565
# ...                ...         ...
# 2020-09-24  146.050003  321.075287
# 2020-09-25  156.029999  326.266083
# 2020-09-28  166.080002  331.685181
# 2020-09-29  163.600006  329.878784
# 2020-09-30  165.259995  332.379944
#
# [128 rows x 2 columns]

# %%
# Load COVID Data
covid_data = pd.read_csv('../ols-stocks-covid/all-states-history.csv', parse_dates=True, index_col=0)
covid_data
# Out:
#            state dataQualityGrade   death  deathConfirmed  deathIncrease  \
# date
# 2020-10-02    WY                B    53.0             NaN              0
# 2020-10-02    NE                A   493.0             NaN             15
# 2020-10-02    ND                B   191.0           188.0              0
# 2020-10-02    NC               A+  3608.0          3579.0             29
# 2020-10-02    MT                C   186.0             NaN              5
# ...          ...              ...     ...             ...            ...
# 2020-01-24    WA              NaN     NaN             NaN              0
# 2020-01-23    WA              NaN     NaN             NaN              0
# 2020-01-23    MA              NaN     NaN             NaN              0
# 2020-01-22    WA              NaN     NaN             NaN              0
# 2020-01-22    MA              NaN     NaN             NaN              0
#
#             deathProbable  hospitalized  hospitalizedCumulative  \
# date
# 2020-10-02            NaN         280.0                   280.0
# 2020-10-02            NaN        2356.0                  2356.0
# 2020-10-02            3.0         902.0                   902.0
# 2020-10-02           29.0           NaN                     NaN
# 2020-10-02            NaN         729.0                   729.0
# ...                   ...           ...                     ...
# 2020-01-24            NaN           NaN                     NaN
# 2020-01-23            NaN           NaN                     NaN
# 2020-01-23            NaN           NaN                     NaN
# 2020-01-22            NaN           NaN                     NaN
# 2020-01-22            NaN           NaN                     NaN
#
#             hospitalizedCurrently  hospitalizedIncrease  ...  \
# date                                                     ...
# 2020-10-02                   32.0                     6  ...
# 2020-10-02                  227.0                     7  ...
# 2020-10-02                  111.0                    18  ...
# 2020-10-02                  921.0                     0  ...
# 2020-10-02                  177.0                     2  ...
# ...                           ...                   ...  ...
# 2020-01-24                    NaN                     0  ...
# 2020-01-23                    NaN                     0  ...
# 2020-01-23                    NaN                     0  ...
# 2020-01-22                    NaN                     0  ...
# 2020-01-22                    NaN                     0  ...
#
#             totalTestResults  totalTestResultsIncrease  totalTestsAntibody  \
# date
# 2020-10-02          103278.0                      1983                 NaN
# 2020-10-02          464264.0                      4722                 NaN
# 2020-10-02          626450.0                      7119              9731.0
# 2020-10-02         3099704.0                     36043                 NaN
# 2020-10-02          353362.0                      4653                 NaN
# ...                      ...                       ...                 ...
# 2020-01-24               0.0                         0                 NaN
# 2020-01-23               0.0                         0                 NaN
# 2020-01-23               2.0                         1                 NaN
# 2020-01-22               0.0                         0                 NaN
# 2020-01-22               1.0                         0                 NaN
#
#             totalTestsAntigen  totalTestsPeopleAntibody  \
# date
# 2020-10-02                NaN                       NaN
# 2020-10-02                NaN                       NaN
# 2020-10-02                NaN                       NaN
# 2020-10-02             3063.0                       NaN
# 2020-10-02                NaN                       NaN
# ...                       ...                       ...
# 2020-01-24                NaN                       NaN
# 2020-01-23                NaN                       NaN
# 2020-01-23                NaN                       NaN
# 2020-01-22                NaN                       NaN
# 2020-01-22                NaN                       NaN
#
#             totalTestsPeopleAntigen  totalTestsPeopleViral  \
# date
# 2020-10-02                      NaN               102353.0
# 2020-10-02                      NaN               464576.0
# 2020-10-02                      NaN               244312.0
# 2020-10-02                      NaN                    NaN
# 2020-10-02                      NaN                    NaN
# ...                             ...                    ...
# 2020-01-24                      NaN                    NaN
# 2020-01-23                      NaN                    NaN
# 2020-01-23                      NaN                    NaN
# 2020-01-22                      NaN                    NaN
# 2020-01-22                      NaN                    NaN
#
#             totalTestsPeopleViralIncrease  totalTestsViral  \
# date
# 2020-10-02                           2095         165242.0
# 2020-10-02                           4731         634687.0
# 2020-10-02                           1412         649885.0
# 2020-10-02                              0        3094417.0
# 2020-10-02                              0         353362.0
# ...                                   ...              ...
# 2020-01-24                              0              NaN
# 2020-01-23                              0              NaN
# 2020-01-23                              0              2.0
# 2020-01-22                              0              NaN
# 2020-01-22                              0              1.0
#
#             totalTestsViralIncrease
# date
# 2020-10-02                     1454
# 2020-10-02                     9733
# 2020-10-02                     7432
# 2020-10-02                    35876
# 2020-10-02                     4653
# ...                             ...
# 2020-01-24                        0
# 2020-01-23                        0
# 2020-01-23                        1
# 2020-01-22                        0
# 2020-01-22                        1
#
# [11914 rows x 42 columns]

# %%
covid = covid_data.groupby('date').sum()[['deathIncrease']]

start_date = '2020-03-31'
end_date = '2020-10-01'

covid = covid.loc[start_date:end_date]
covid
# Out:
#             deathIncrease
# date
# 2020-03-31            890
# 2020-04-01           1011
# 2020-04-02           1172
# 2020-04-03           1286
# 2020-04-04           1482
# ...                   ...
# 2020-09-27            307
# 2020-09-28            257
# 2020-09-29            739
# 2020-09-30           1061
# 2020-10-01            851
#
# [185 rows x 1 columns]

# %%
df_comb = stocks.join(covid)
df_comb
# Out:
#                     BA         SPY  deathIncrease
# Date
# 2020-03-31  149.139999  253.681808            890
# 2020-04-01  130.699997  242.264893           1011
# 2020-04-02  123.269997  247.855255           1172
# 2020-04-03  124.519997  244.272705           1286
# 2020-04-06  148.770004  260.679565           1318
# ...                ...         ...            ...
# 2020-09-24  146.050003  321.075287            921
# 2020-09-25  156.029999  326.266083            844
# 2020-09-28  166.080002  331.685181            257
# 2020-09-29  163.600006  329.878784            739
# 2020-09-30  165.259995  332.379944           1061
#
# [128 rows x 3 columns]

# %%
df_comb
# Out:
#                     BA         SPY  deathIncrease
# Date
# 2020-03-31  149.139999  253.681808            890
# 2020-04-01  130.699997  242.264893           1011
# 2020-04-02  123.269997  247.855255           1172
# 2020-04-03  124.519997  244.272705           1286
# 2020-04-06  148.770004  260.679565           1318
# ...                ...         ...            ...
# 2020-09-24  146.050003  321.075287            921
# 2020-09-25  156.029999  326.266083            844
# 2020-09-28  166.080002  331.685181            257
# 2020-09-29  163.600006  329.878784            739
# 2020-09-30  165.259995  332.379944           1061
#
# [128 rows x 3 columns]

# %%
df_comb.to_csv('./clean_stocks_and_covid.csv')
